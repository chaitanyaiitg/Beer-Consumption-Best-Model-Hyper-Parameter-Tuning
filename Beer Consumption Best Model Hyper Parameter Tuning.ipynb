# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'F:\Data_Science\Drink Consumption\Consumo_cerveja.csv',thousands='.', decimal=',')

# %%
df
# Out:
#            Data  Temperatura Media (C)  Temperatura Minima (C)  \
# 0    2015-01-01                  27.30                    23.9
# 1    2015-01-02                  27.02                    24.5
# 2    2015-01-03                  24.82                    22.4
# 3    2015-01-04                  23.98                    21.5
# 4    2015-01-05                  23.82                    21.0
# ..          ...                    ...                     ...
# 936         NaN                    NaN                     NaN
# 937         NaN                    NaN                     NaN
# 938         NaN                    NaN                     NaN
# 939         NaN                    NaN                     NaN
# 940         NaN                    NaN                     NaN
#
#      Temperatura Maxima (C)  Precipitacao (mm)  Final de Semana  \
# 0                      32.5                0.0              0.0
# 1                      33.5                0.0              0.0
# ...

# %%
df.shape
# Out:
# (941, 7)

# %%
df.columns
# Out:
# Index(['Data', 'Temperatura Media (C)', 'Temperatura Minima (C)',
#        'Temperatura Maxima (C)', 'Precipitacao (mm)', 'Final de Semana',
#        'Consumo de cerveja (litros)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Data                            object
# Temperatura Media (C)          float64
# Temperatura Minima (C)         float64
# Temperatura Maxima (C)         float64
# Precipitacao (mm)              float64
# Final de Semana                float64
# Consumo de cerveja (litros)    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Data                           576
# Temperatura Media (C)          576
# Temperatura Minima (C)         576
# Temperatura Maxima (C)         576
# Precipitacao (mm)              576
# Final de Semana                576
# Consumo de cerveja (litros)    576
# dtype: int64

# %%
df.nunique()
# Out:
# Data                           365
# Temperatura Media (C)          277
# Temperatura Minima (C)         110
# Temperatura Maxima (C)         151
# Precipitacao (mm)               93
# Final de Semana                  2
# Consumo de cerveja (litros)    359
# dtype: int64

# %%
missing_percentage=((df.isnull().sum()*100)/df.shape[0])
print(missing_percentage)
# Out:
# Data                           61.211477
# Temperatura Media (C)          61.211477
# Temperatura Minima (C)         61.211477
# Temperatura Maxima (C)         61.211477
# Precipitacao (mm)              61.211477
# Final de Semana                61.211477
# Consumo de cerveja (litros)    61.211477
# dtype: float64

# %%
df.describe()
# Out:
#        Temperatura Media (C)  Temperatura Minima (C)  Temperatura Maxima (C)  \
# count             365.000000              365.000000              365.000000
# mean               21.226356               17.461370               26.611507
# std                 3.180108                2.826185                4.317366
# min                12.900000               10.600000               14.500000
# 25%                19.020000               15.300000               23.800000
# 50%                21.380000               17.900000               26.900000
# 75%                23.280000               19.600000               29.400000
# max                28.860000               24.500000               36.500000
#
#        Precipitacao (mm)  Final de Semana  Consumo de cerveja (litros)
# count         365.000000       365.000000                   365.000000
# mean            5.196712         0.284932                 25401.367123
# ...

# %%
df.isnull().sum()
# Out:
# Data                           576
# Temperatura Media (C)          576
# Temperatura Minima (C)         576
# Temperatura Maxima (C)         576
# Precipitacao (mm)              576
# Final de Semana                576
# Consumo de cerveja (litros)    576
# dtype: int64

# %%
df.loc[:,df.isnull().any()]
# Out:
#            Data  Temperatura Media (C)  Temperatura Minima (C)  \
# 0    2015-01-01                  27.30                    23.9
# 1    2015-01-02                  27.02                    24.5
# 2    2015-01-03                  24.82                    22.4
# 3    2015-01-04                  23.98                    21.5
# 4    2015-01-05                  23.82                    21.0
# ..          ...                    ...                     ...
# 936         NaN                    NaN                     NaN
# 937         NaN                    NaN                     NaN
# 938         NaN                    NaN                     NaN
# 939         NaN                    NaN                     NaN
# 940         NaN                    NaN                     NaN
#
#      Temperatura Maxima (C)  Precipitacao (mm)  Final de Semana  \
# 0                      32.5                0.0              0.0
# 1                      33.5                0.0              0.0
# ...

# %%
sns.heatmap(df.isnull())

# %%
df=df.dropna(how='all')
df
# Out:
#            Data  Temperatura Media (C)  Temperatura Minima (C)  \
# 0    2015-01-01                  27.30                    23.9
# 1    2015-01-02                  27.02                    24.5
# 2    2015-01-03                  24.82                    22.4
# 3    2015-01-04                  23.98                    21.5
# 4    2015-01-05                  23.82                    21.0
# ..          ...                    ...                     ...
# 360  2015-12-27                  24.00                    21.1
# 361  2015-12-28                  22.64                    21.1
# 362  2015-12-29                  21.68                    20.3
# 363  2015-12-30                  21.38                    19.3
# 364  2015-12-31                  24.76                    20.2
#
#      Temperatura Maxima (C)  Precipitacao (mm)  Final de Semana  \
# 0                      32.5                0.0              0.0
# 1                      33.5                0.0              0.0
# ...

# %%
df['Data']=pd.to_datetime(df['Data'])
df
# Out:
#           Data  Temperatura Media (C)  Temperatura Minima (C)  \
# 0   2015-01-01                  27.30                    23.9
# 1   2015-01-02                  27.02                    24.5
# 2   2015-01-03                  24.82                    22.4
# 3   2015-01-04                  23.98                    21.5
# 4   2015-01-05                  23.82                    21.0
# ..         ...                    ...                     ...
# 360 2015-12-27                  24.00                    21.1
# 361 2015-12-28                  22.64                    21.1
# 362 2015-12-29                  21.68                    20.3
# 363 2015-12-30                  21.38                    19.3
# 364 2015-12-31                  24.76                    20.2
#
#      Temperatura Maxima (C)  Precipitacao (mm)  Final de Semana  \
# 0                      32.5                0.0              0.0
# 1                      33.5                0.0              0.0
# ...

# %%
sns.distplot(df['Consumo de cerveja (litros)'])

# %%
sns.boxplot(df['Consumo de cerveja (litros)'])

# %%
df['Consumo de cerveja (litros)'].describe()
# Out:
# count      365.000000
# mean     25401.367123
# std       4399.142703
# min      14343.000000
# 25%      22008.000000
# 50%      24867.000000
# 75%      28631.000000
# max      37937.000000
# Name: Consumo de cerveja (litros), dtype: float64

# %%
#colors=colors=['r','g','b','m','c','y','teal','thistle','tomato','turquoise','violet','yellowgreen','coral','cornflowerblue','crimson','cyan','darkblue','darkcyan','darkslategray','darkturquoise','khaki','b','lawngreen','m','lightcoral','y','darkgreen','darkkhaki','darkmagenta','darkolivegreen','gold','goldenrod','darkred','darksalmon','darkseagreen','darkslateblue','darkviolet','deeppink','deepskyblue','darkgray','dodgerblue','firebrick','skyblue','forestgreen','fuchsia','pink','green','gray','green','greenyellow','red','hotpink','indianred']

# %%
df.dtypes
# Out:
# Data                           datetime64[ns]
# Temperatura Media (C)                 float64
# Temperatura Minima (C)                float64
# Temperatura Maxima (C)                float64
# Precipitacao (mm)                     float64
# Final de Semana                       float64
# Consumo de cerveja (litros)           float64
# dtype: object

# %%
sns.relplot(x='Data',y='Consumo de cerveja (litros)',kind='line',data=df,palette="Set1",aspect=2.5)

# %%
df.columns
# Out:
# Index(['Data', 'Temperatura Media (C)', 'Temperatura Minima (C)',
#        'Temperatura Maxima (C)', 'Precipitacao (mm)', 'Final de Semana',
#        'Consumo de cerveja (litros)'],
#       dtype='object')

# %%
cols=['Temperatura Media (C)', 'Temperatura Minima (C)',
       'Temperatura Maxima (C)', 'Precipitacao (mm)', 'Final de Semana']
for i in cols:
    sns.lmplot(x=i, y='Consumo de cerveja (litros)', data=df)
    plt.title('%s vs %s'%(i,'Consumo de cerveja (litros)') )
#plt.scatter(x='SIXERS', y='SOLD PRICE', data=data_Allrounder)

# %%
sns.lmplot(x='Precipitacao (mm)', y='Consumo de cerveja (litros)', data=df)

# %%
sns.catplot(x='Final de Semana', y='Consumo de cerveja (litros)', data=df, kind='box')

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True,cmap='RdYlGn')

# %%
X=df.drop(['Data','Consumo de cerveja (litros)'],axis=1)

# %%
X
# Out:
#      Temperatura Media (C)  Temperatura Minima (C)  Temperatura Maxima (C)  \
# 0                    27.30                    23.9                    32.5
# 1                    27.02                    24.5                    33.5
# 2                    24.82                    22.4                    29.9
# 3                    23.98                    21.5                    28.6
# 4                    23.82                    21.0                    28.3
# ..                     ...                     ...                     ...
# 360                  24.00                    21.1                    28.2
# 361                  22.64                    21.1                    26.7
# 362                  21.68                    20.3                    24.1
# 363                  21.38                    19.3                    22.4
# 364                  24.76                    20.2                    29.0
#
#      Precipitacao (mm)  Final de Semana
# ...

# %%
y=df['Consumo de cerveja (litros)']

# %%
y
# Out:
# 0      25461.0
# 1      28972.0
# 2      30814.0
# 3      29799.0
# 4      28900.0
#         ...
# 360    32307.0
# 361    26095.0
# 362    22309.0
# 363    20467.0
# 364    22446.0
# Name: Consumo de cerveja (litros), Length: 365, dtype: float64

# %%
from sklearn.ensemble import ExtraTreesRegressor
selection = ExtraTreesRegressor()
selection.fit(X, y)
# Out:
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [0.18594735 0.08081798 0.39870927 0.07919611 0.25532929]

# %%
plt.figure(figsize=(15,10))
feature_imp=pd.Series(selection.feature_importances_, index=X.columns)
feature_imp.nlargest(25).plot(kind='barh')

# %%
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge

from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=25)

# %%
s=StandardScaler()
X_train=s.fit_transform(X_train)
X_test=s.transform(X_test)

# %%
lasso=Lasso()
lasso.fit(X_train,y_train)
lasso.score(X_test,y_test)
# Out:
# 0.6575919633021048

# %%
algo=[]
value=[]
def cross_val_score_model(model,name):
    cv = ShuffleSplit(n_splits=5, test_size=0.25, random_state=25)
    cv_score=cross_val_score(model,X,y,cv=cv).mean()
    print('CV_Score' + ' '+ str(name) +': '+ str(cv_score))
    algo.append(name)
    value.append(cv_score)
    
cross_val_score_model(Lasso(),'Lasso')
cross_val_score_model(Ridge(),'Ridge')
cross_val_score_model(KNeighborsRegressor(),'KNeighborsRegressor')
cross_val_score_model(LinearRegression(),'LinearRegression')
cross_val_score_model(DecisionTreeRegressor(),'DecisionTreeRegressor')
cross_val_score_model(RandomForestRegressor(),'RandomForestRegressor')
cross_val_score_model(XGBRegressor(),'XGBRegressor')
# Out:
# CV_Score Lasso: 0.7175194157919276
# CV_Score Ridge: 0.7176805782372592
# CV_Score KNeighborsRegressor: 0.4030521925686374
# CV_Score LinearRegression: 0.7174712346984844
# CV_Score DecisionTreeRegressor: 0.3944629137003651
# CV_Score RandomForestRegressor: 0.6345338344168596
# CV_Score XGBRegressor: 0.5884359785272626

# %%
model_params={                  
    'Lasso':{
        'model':Lasso(),
        'params':{
            'max_iter' : [1000,1200,1300,1500]
            
        }
    },
       'Ridge:':{
        'model':Ridge(),
        'params':{
            'max_iter' : [1000,1200,1300,1500]
            
        }
    },
     'LinearRegression:':{
        'model':LinearRegression(),
        'params':{
            'n_jobs' : [100,200,300,500]
            
        }
    },
        'RandomForestRegressor':{
        'model':RandomForestRegressor(),
        'params':{
            'n_estimators' :[100,300,500,800,1000, 1200],
            'max_features' : ['auto', 'sqrt'],
            'max_depth' : [5,10,15,20,25,30,35,40,45,50]
        }
    },
    'XGBRegressor':{
        'model':XGBRegressor(),
        'params':{
            'n_estimators' : [100, 500, 1000, 1300, 1500],
            'max_depth' : [2, 3, 5, 10, 15],
            'booster':['gbtree','gblinear'],
            'learning_rate':[0.05,0.1,0.15,0.20],
            'min_child_weight':[1,2,3,4],
            'base_score':[0.25,0.5,0.75,1]
        }
    }

}

# %%
scores=[]
cv = ShuffleSplit(n_splits=5, test_size=0.25, random_state=25)
for model_name, mp in model_params.items():
    random_clf=RandomizedSearchCV(mp['model'],mp['params'],scoring='neg_mean_squared_error', n_iter = 5, cv = cv, verbose=2, n_jobs = 1, return_train_score=False)
    random_clf.fit(X,y)
    scores.append({
        'model':model_name,
        'best_score':random_clf.best_score_,
        'best param':random_clf.best_params_,
        'best estimator':random_clf.best_estimator_
    })

ds=pd.DataFrame(scores,columns=['model','best param'])
ds
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] max_iter=1000 ...................................................
# [CV] .................................... max_iter=1000, total=   0.0s
# [CV] max_iter=1000 ...................................................
# [CV] .................................... max_iter=1000, total=   0.0s
# [CV] max_iter=1000 ...................................................
# [CV] .................................... max_iter=1000, total=   0.0s
# [CV] max_iter=1000 ...................................................
# [CV] .................................... max_iter=1000, total=   0.0s
# [CV] max_iter=1000 ...................................................
# [CV] .................................... max_iter=1000, total=   0.0s
# [CV] max_iter=1200 ...................................................
# [CV] .................................... max_iter=1200, total=   0.0s
# ...

# %%
def display_text_max_col_width(df, width):
    with pd.option_context('display.max_colwidth', width):
        print(df)

display_text_max_col_width(ds['best param'], 800)
# Out:
# 0                                                                                                             {'max_iter': 1000}
# 1                                                                                                             {'max_iter': 1000}
# 2                                                                                                                {'n_jobs': 100}
# 3                                                                {'n_estimators': 1200, 'max_features': 'sqrt', 'max_depth': 20}
# 4    {'n_estimators': 1500, 'min_child_weight': 1, 'max_depth': 2, 'learning_rate': 0.2, 'booster': 'gblinear', 'base_score': 1}
# Name: best param, dtype: object

# %%
cross_val_score_model(Lasso(max_iter=1000),'Lasso_best')
cross_val_score_model(Ridge(max_iter=1000),'Ridge_best')
cross_val_score_model(LinearRegression(n_jobs=100),'LinearRegression_best')
cross_val_score_model(RandomForestRegressor(n_estimators=1200, max_features='sqrt', max_depth=20),'RandomForestRegressor_best')
cross_val_score_model(XGBRegressor(n_estimators= 1500, min_child_weight= 1, max_depth=2, learning_rate=0.2, booster='gblinear', base_score=1),'XGBRegressor_best')
# Out:
# CV_Score Lasso_best: 0.7175194157919276
# CV_Score Ridge_best: 0.7176805782372592
# CV_Score LinearRegression_best: 0.7174712346984844
# CV_Score RandomForestRegressor_best: 0.6489790713496701
# [00:09:40] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_depth, min_child_weight } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:09:40] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_depth, min_child_weight } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
# ...

# %%
sns.barplot(x=value,y=algo)
plt.show()

# %%
Best1=pd.Series(algo)
Best2=pd.Series(value)
pd.DataFrame({'Model':Best1,'CVScore':Best2})
# Out:
#                          Model   CVScore
# 0                        Lasso  0.717519
# 1                        Ridge  0.717681
# 2          KNeighborsRegressor  0.403052
# 3             LinearRegression  0.717471
# 4        DecisionTreeRegressor  0.394463
# 5        RandomForestRegressor  0.634534
# 6                 XGBRegressor  0.588436
# 7                   Lasso_best  0.717519
# 8                   Ridge_best  0.717681
# 9        LinearRegression_best  0.717471
# 10  RandomForestRegressor_best  0.648979
# 11           XGBRegressor_best  0.716500

# %% [markdown]
# # Best Model XGBRegressor with Hyper Parameter Tuning

# %%
from sklearn import metrics
from sklearn.metrics import r2_score
rid=Ridge()
rid.fit(X_train,y_train)
rid_y_pred=rid.predict(X_test)
score=r2_score(y_test,rid_y_pred)
score
# Out:
# 0.6571561182663943

# %%
plt.figure(figsize=(10,6))
sns.distplot(y_test-rid_y_pred)

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,rid_y_pred)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, rid_y_pred))
print('MSE:', metrics.mean_squared_error(y_test, rid_y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, rid_y_pred)))
# Out:
# MAE: 2034.5470195637308
# MSE: 6177742.159918871
# RMSE: 2485.506419206933

# %%
df.iloc[1]
# Out:
# Data                           2015-01-02 00:00:00
# Temperatura Media (C)                        27.02
# Temperatura Minima (C)                        24.5
# Temperatura Maxima (C)                        33.5
# Precipitacao (mm)                                0
# Final de Semana                                  0
# Consumo de cerveja (litros)                  28972
# Name: 1, dtype: object

# %%
a=[[27.02,24.5,33.5,0,0]]
a=s.transform(a)
b=rid.predict(a)
b
# Out:
# array([28426.84820761])
